# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

img = cv2.imread('moon.tif', 0)
cv2_imshow(img)
height = int(img.shape[0])
width = int(img.shape[1])
#create kernel
w = np.zeros([3,3])
for x in range(0,3):
  for y in range(0,3):
    w[x,y] = 1
w = w * 1/9

#zero-padding the image
img = cv2.copyMakeBorder(img, 1, 1, 1, 1, cv2.BORDER_CONSTANT)

#applying correlation
for x in range(0,(height-2)):
  for y in range(0,(width-2)):
    img[x+1][y+1] = w[0][0]*img[x][y] + w[0][1]*img[x+1][y] + w[0][2]*img[x+2][y] + w[1][0]*img[x][y+1] + w[1][1]*img[x+1][y+1] + w[1][2]*img[x+2][y+1] + w[2][0]*img[x][y+2] + w[2][1]*img[x+1][y+2] + w[2][2]*img[x+2][y+2]
print("After filter:")
cv2_imshow(img)

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

img = cv2.imread('moon.tif', 0)
cv2_imshow(img)
height = int(img.shape[0])
width = int(img.shape[1])
#create kernel
w = np.zeros([3,3])
w[0,0] = 1
w[1,0] = 2
w[2,0] = 1
w[0,1] = 2
w[1,1] = 4
w[2,1] = 2
w[0,2] = 1
w[1,2] = 2
w[2,2] = 1
w = w * 1/16

#zero-padding the image
#img = cv2.copyMakeBorder(img, 1, 1, 1, 1, cv2.BORDER_CONSTANT)

#applying correlation
for x in range(0,(height-2)):
  for y in range(0,(width-2)):
    img[x+1][y+1] = w[0][0]*img[x][y] + w[0][1]*img[x+1][y] + w[0][2]*img[x+2][y] + w[1][0]*img[x][y+1] + w[1][1]*img[x+1][y+1] + w[1][2]*img[x+2][y+1] + w[2][0]*img[x][y+2] + w[2][1]*img[x+1][y+2] + w[2][2]*img[x+2][y+2]

print("After filter:")
cv2_imshow(img)
"""
output = cv2.GaussianBlur(img,(5,5),cv2.BORDER_DEFAULT)
cv2_imshow(output)
"""

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

img = cv2.imread('hubble.tif',0)
cv2_imshow(img)
height = int(img.shape[0])
width = int(img.shape[1])

print("Gaussian Blur:")
output = cv2.GaussianBlur(img,(0,0),cv2.BORDER_DEFAULT)
cv2_imshow(output)


"""
print("Mediann Blur:")
output = cv2.medianBlur(img,5)
cv2_imshow(output)
"""

#creating mask
mask = np.zeros([height,width])
for x in range(0,height):
  for y in range(0,width):
    if output[x,y] < 100:
      mask[x,y] = 0
    else:
      mask[x,y] = 255
print("Mask of Smoothed Image:")
cv2_imshow(mask)

new = np.zeros([height,width])
for x in range(0,height):
  for y in range(0,width):
    new[x,y] = mask [x,y] and output [x,y] 
print("Applying mask:")
cv2_imshow(new)

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

img = cv2.imread('hubble.tif', 0)
cv2_imshow(img)
height = int(img.shape[0])
width = int(img.shape[1])

mask = np.zeros([height,width])
for x in range(0,height):
  for y in range(0,width):
    if img[x,y] < 128:
      mask[x,y] = 0
    else:
      mask[x,y] = 255
print("Mask of Original Image:")
cv2_imshow(mask)

new = np.zeros([height,width])
for x in range(0,height):
  for y in range(0,width):
    new[x,y] = mask [x,y] and img [x,y] 
print("Applying mask:")
cv2_imshow(new)

#create kernel
w = np.zeros([3,3])
for x in range(0,3):
  for y in range(0,3):
    w[x,y] = 1
w = w * 1/9

#zero-padding the image
img = cv2.copyMakeBorder(img, 1, 1, 1, 1, cv2.BORDER_CONSTANT)

#applying correlation
for x in range(0,(height-2)):
  for y in range(0,(width-2)):
    img[x+1][y+1] = w[0][0]*img[x][y] + w[0][1]*img[x+1][y] + w[0][2]*img[x+2][y] + w[1][0]*img[x][y+1] + w[1][1]*img[x+1][y+1] + w[1][2]*img[x+2][y+1] + w[2][0]*img[x][y+2] + w[2][1]*img[x+1][y+2] + w[2][2]*img[x+2][y+2]

print("Smoothed Image:")
cv2_imshow(img)

#creating mask
mask = np.zeros([height,width])
for x in range(0,height):
  for y in range(0,width):
    if img[x,y] < 128:
      mask[x,y] = 0
    else:
      mask[x,y] = 255
print("Mask of Smoothed Image:")
cv2_imshow(mask)

new = np.zeros([height,width])
for x in range(0,height):
  for y in range(0,width):
    new[x,y] = mask [x,y] and img [x,y] 
print("Applying mask:")
cv2_imshow(new)
