# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import math

img = cv2.imread('dark.tif',0)

cv2_imshow(img)

h = int(img.shape[0])
w = int(img.shape[1])
count = np.zeros([256])
for y in range(0,w):
  for x in range(0,h):
    val = img[x][y]
    count[val] += 1
plt.plot(count)
plt.xlim([0,256])
plt.show()

#Applying log transformation
c = 255/(np.log(1+np.max(img)))
log_transform = c * np.log(1+img)
log_transform = np.array(log_transform, dtype = np.uint8)
cv2_imshow(log_transform)

count = np.zeros([256])
for y in range(0,w):
  for x in range(0,h):
    val = log_transform[x][y]
    count[val] += 1
plt.plot(count)
plt.xlim([0,256])
plt.show()

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import math
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

img = cv2.imread('dark.tif',0)

#cv2_imshow(img)
h = int(img.shape[0])
w = int(img.shape[1])
print(h,w)
count = np.zeros([256])
"""
for y in range(0,w):
  for x in range(0,h):
    val = img[x][y]
    count[val] += 1
plt.plot(count)
plt.xlim([0,256])
plt.show()"""
new_img = np.zeros([h,w])

def f(g):
  #Applying power transformation
  c = 255
  for y in range(0,w):
    for x in range(0,h):
      r = (img[x][y] / 255)
      new_img[x][y] = c * (r**g)
      
  cv2_imshow(new_img)
  return int(g)
"""
  count = np.zeros([256])
  for y in range(0,w):
    for x in range(0,h):
      val = int(new_img[x][y])
      count[val] += 1
  plt.plot(count)
  plt.xlim([0,256])
  plt.show()
  return int(g)
"""
interact(f, g=(0,2,0.2))
# Out:
# 500 500
# interactive(children=(FloatSlider(value=1.0, description='g', max=2.0, step=0.2), Output()), _dom_classes=('wi…
# <function __main__.f>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('messi5.jpg',0)

cv2_imshow(img)
h = int(img.shape[0])
w = int(img.shape[1])

M = np.float32([[1,0,0],[0.5,1,0]])
new_img = cv2.warpAffine(img,M,(w,h))

cv2_imshow(new_img)

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import math
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

img = cv2.imread('messi5.jpg',0)

#cv2_imshow(img)
h = int(img.shape[0])
w = int(img.shape[1])
print(h,w)
count = np.zeros([256])
"""
for y in range(0,w):
  for x in range(0,h):
    val = img[x][y]
    count[val] += 1
plt.plot(count)
plt.xlim([0,256])
plt.show()
"""
new_img = np.zeros([h,w])
gamma_array = [0]*256
new_img = np.zeros([h,w])
  
def f(g):
  c = 255
  for z in range(0,256):
    gamma_array[z] = c * ((z/255)**g)
  for y in range(0,w):
    for x in range(0,h):
      pixel = int(img[x][y])
      new_img[x][y] = gamma_array[pixel]
  cv2_imshow(new_img)
  return int(g)
interact(f, g=(0,2,0.2))
# Out:
# 280 450
# interactive(children=(FloatSlider(value=1.0, description='g', max=2.0, step=0.2), Output()), _dom_classes=('wi…
# <function __main__.f>
